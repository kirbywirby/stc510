# %%
import pandas as pd

# %%
n = pd.read_csv('/Users/maddie/Downloads/crimestat (1).csv')
n
# Out:
# /var/folders/jk/2mphqzcs24zdkswz0vgc04rm0000gn/T/ipykernel_49533/2884405311.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   n = pd.read_csv('/Users/maddie/Downloads/crimestat (1).csv')
#                INC NUMBER    OCCURRED ON    OCCURRED TO   UCR CRIME CATEGORY  \
# 0               2.016E+14   11/1/15 0:00    1/9/16 0:00  MOTOR VEHICLE THEFT
# 1               2.016E+14   11/1/15 0:00            NaN                 RAPE
# 2               2.015E+14   11/1/15 0:00   11/1/15 9:00        LARCENY-THEFT
# 3               2.015E+14   11/1/15 0:00   11/1/15 5:00  MOTOR VEHICLE THEFT
# 4               2.015E+14   11/1/15 0:00  11/1/15 11:50  MOTOR VEHICLE THEFT
# ...                   ...            ...            ...                  ...
# 131672  201700000000000.0  11/17/17 4:15  11/17/17 4:30        LARCENY-THEFT
# 131673  201700000000000.0  11/17/17 5:00  11/17/17 9:50  MOTOR VEHICLE THEFT
# ...

# %%
n.sort_values(by='ZIP')
# Out:
#         INC NUMBER    OCCURRED ON    OCCURRED TO   UCR CRIME CATEGORY  \
# 31858    2.016E+14   5/7/16 22:00   5/7/16 22:15   AGGRAVATED ASSAULT
# 115394   2.017E+14   8/20/17 2:00            NaN   AGGRAVATED ASSAULT
# 15421   2.0168E+11  1/31/16 16:20            NaN        LARCENY-THEFT
# 130262   2.017E+14  11/8/17 18:27  11/8/17 18:27         DRUG OFFENSE
# 40784    2.016E+14  6/28/16 16:00            NaN  MOTOR VEHICLE THEFT
# ...            ...            ...            ...                  ...
# 115872   2.017E+14   8/23/17 0:00            NaN        LARCENY-THEFT
# 113612   2.017E+14  8/10/17 17:00  8/11/17 15:00  MOTOR VEHICLE THEFT
# 63086    2.017E+14   11/4/16 0:00   6/25/17 0:00                 RAPE
# 79792    2.017E+14   2/4/17 10:00   2/4/17 10:14        LARCENY-THEFT
# 82369    2.017E+14  2/18/17 12:00  2/27/17 15:23        LARCENY-THEFT
#
#                     100 BLOCK ADDR      ZIP  \
# 31858   S 7TH AVE & W JEFFERSON ST  85003.0
# ...

# %% [markdown]
# Total crime count in each zip.

# %%
n.ZIP.value_counts()
# Out:
# ZIP
# 85015.0    6963
# 85008.0    6320
# 85009.0    5513
# 85041.0    5477
# 85051.0    5389
#            ...
# 85203.0       1
# 85266.0       1
# 85381.0       1
# 85268.0       1
# 85212.0       1
# Name: count, Length: 98, dtype: int64

# %% [markdown]
# How many times each type of crime has occured

# %%
n['UCR CRIME CATEGORY'].value_counts()
# Out:
# UCR CRIME CATEGORY
# LARCENY-THEFT                            66216
# BURGLARY                                 23648
# MOTOR VEHICLE THEFT                      14391
# DRUG OFFENSE                              9572
# AGGRAVATED ASSAULT                        9306
# ROBBERY                                   5640
# RAPE                                      1981
# ARSON                                      634
# MURDER AND NON-NEGLIGENT MANSLAUGHTER      289
# Name: count, dtype: int64

# %% [markdown]
# Grouping by ZIP

# %%
nzip = n.groupby('ZIP')

# %% [markdown]
# Doing value counts by crime category to see which types of crime are most common in each zip.

# %%
nzip['UCR CRIME CATEGORY'].value_counts()
# Out:
# ZIP      UCR CRIME CATEGORY
# 85003.0  LARCENY-THEFT          758
#          DRUG OFFENSE           194
#          BURGLARY               179
#          MOTOR VEHICLE THEFT    128
#          AGGRAVATED ASSAULT     120
#                                ...
# 85395.0  RAPE                     1
#          AGGRAVATED ASSAULT       1
# 85396.0  LARCENY-THEFT            2
#          BURGLARY                 1
#          MOTOR VEHICLE THEFT      1
# Name: count, Length: 561, dtype: int64

# %% [markdown]
# Now grouping by UCR CRIME CATEGORY.

# %%
ntype = n.groupby('UCR CRIME CATEGORY')

# %% [markdown]
# Looking at how many times each crime type occured in each zip code. Using print and .to_string to see full list.

# %%
print(ntype['ZIP'].value_counts().to_string())
# Out:
# UCR CRIME CATEGORY                     ZIP
# AGGRAVATED ASSAULT                     85008.0     516
#                                        85009.0     482
#                                        85017.0     476
#                                        85015.0     476
#                                        85041.0     429
#                                        85051.0     389
#                                        85035.0     369
#                                        85033.0     359
#                                        85040.0     347
#                                        85043.0     343
#                                        85021.0     329
#                                        85029.0     273
#                                        85032.0     268
#                                        85019.0     258
#                                        85031.0     250
#                                        85006.0     248
# ...

# %% [markdown]
# Looking at count of location types for each crime category.

# %%
print(ntype['PREMISE TYPE'].value_counts().to_string())
# Out:
# UCR CRIME CATEGORY                     PREMISE TYPE
# AGGRAVATED ASSAULT                     APARTMENT                                2167
#                                        STREET / ROADWAY / ALLEY / SIDEWALK      2060
#                                        SINGLE FAMILY HOUSE                      2033
#                                        PARKING LOT                               724
#                                        PARK / PLAYGROUND                         233
#                                        VEHICLE                                   224
#                                        CONVENIENCE MARKET / STORE                155
#                                        HOTEL / MOTEL                             153
#                                        BAR / LOUNG / NIGHT CLUB                  113
#                                        MOBILE HOME                               101
# ...

# %% [markdown]
# Adding columns year and month to dataframe. Using DatetimeIndex to get the month and year from column 'OCCURRED ON'.
#
# I found this on Stack Overflow and was worried that it wouldn't work. Really excited that it did!

# %%
n['OCCURRED ON'].describe
# Out:
# <bound method NDFrame.describe of 0          11/1/15 0:00
# 1          11/1/15 0:00
# 2          11/1/15 0:00
# 3          11/1/15 0:00
# 4          11/1/15 0:00
#               ...
# 131672    11/17/17 4:15
# 131673    11/17/17 5:00
# 131674    11/17/17 5:34
# 131675    11/17/17 5:50
# 131676    11/17/17 6:00
# Name: OCCURRED ON, Length: 131677, dtype: object>

# %%
n['year'] = pd.DatetimeIndex(n['OCCURRED ON']).year
n['month'] = pd.DatetimeIndex(n['OCCURRED ON']).month

# %%
n
# Out:
#                INC NUMBER    OCCURRED ON    OCCURRED TO   UCR CRIME CATEGORY  \
# 0               2.016E+14   11/1/15 0:00    1/9/16 0:00  MOTOR VEHICLE THEFT
# 1               2.016E+14   11/1/15 0:00            NaN                 RAPE
# 2               2.015E+14   11/1/15 0:00   11/1/15 9:00        LARCENY-THEFT
# 3               2.015E+14   11/1/15 0:00   11/1/15 5:00  MOTOR VEHICLE THEFT
# 4               2.015E+14   11/1/15 0:00  11/1/15 11:50  MOTOR VEHICLE THEFT
# ...                   ...            ...            ...                  ...
# 131672  201700000000000.0  11/17/17 4:15  11/17/17 4:30        LARCENY-THEFT
# 131673  201700000000000.0  11/17/17 5:00  11/17/17 9:50  MOTOR VEHICLE THEFT
# 131674  201700000000000.0  11/17/17 5:34            NaN   AGGRAVATED ASSAULT
# 131675  201700000000000.0  11/17/17 5:50  11/17/17 7:50             BURGLARY
# 131676  201700000000000.0  11/17/17 6:00  11/30/17 6:00             BURGLARY
#
# ...

# %% [markdown]
# Looking at number of each crime category each year

# %%
ntype.year.value_counts()
# Out:
# UCR CRIME CATEGORY                     year
# AGGRAVATED ASSAULT                     2017.0     4586
#                                        2016.0     4105
#                                        2015.0      582
# ARSON                                  2017.0      324
#                                        2016.0      275
#                                        2015.0       33
# BURGLARY                               2016.0    11510
#                                        2017.0    10080
#                                        2015.0     2013
# DRUG OFFENSE                           2016.0     4647
#                                        2017.0     4292
#                                        2015.0      614
# LARCENY-THEFT                          2016.0    31821
#                                        2017.0    29034
#                                        2015.0     5188
# MOTOR VEHICLE THEFT                    2016.0     7220
# ...

# %% [markdown]
# Getting crime count per zip code for each year

# %%
print(nzip.year.value_counts().to_string())
# Out:
# ZIP      year
# 85003.0  2017.0     721
#          2016.0     656
#          2015.0     134
# 85004.0  2016.0     822
#          2017.0     722
#          2015.0     101
# 85006.0  2016.0    1249
#          2017.0    1231
#          2015.0     174
# 85007.0  2016.0     964
#          2017.0     864
#          2015.0     168
# 85008.0  2016.0    3034
#          2017.0    2858
#          2015.0     416
# 85009.0  2016.0    2552
#          2017.0    2498
#          2015.0     440
# 85012.0  2016.0     386
#          2017.0     379
#          2015.0      58
# 85013.0  2016.0    1354
#          2017.0    1276
#          2015.0     184
# 85014.0  2016.0    1122
#          2017.0     943
#          2015.0     203
# 85015.0  2016.0    3447
#          2017.0    2927
#          2015.0     549
# 85016.0  2016.0    1897
#          2017.0    1562
#          2015.0     328
# 85017.0  2016.0    2512
#          2017.0    2421
#          2015.0     408
# 85018.0  2016.0    1390
# ...

# %% [markdown]
# Looking at crime count per type in each month each year

# %%
print(ntype[['month','year']].value_counts().to_string())
# Out:
# UCR CRIME CATEGORY                     month  year
# AGGRAVATED ASSAULT                     10.0   2017.0     490
#                                        8.0    2017.0     482
#                                        5.0    2017.0     474
#                                        4.0    2017.0     457
#                                        9.0    2017.0     456
#                                        3.0    2017.0     432
#                                        7.0    2017.0     426
#                                        6.0    2017.0     416
#                                        11.0   2016.0     386
#                                        3.0    2016.0     374
#                                        2.0    2017.0     366
#                                        12.0   2016.0     363
#                                        7.0    2016.0     361
#                                        8.0    2016.0     359
#                                        9.0    2016.0     357
# ...

# %% [markdown]
# Getting crime count in each zip in each month each year

# %%
print(nzip[['month','year']].value_counts().to_string())
# Out:
# ZIP      month  year
# 85003.0  10.0   2017.0     90
#          8.0    2017.0     83
#          3.0    2017.0     72
#          11.0   2015.0     69
#          4.0    2017.0     69
#          7.0    2017.0     69
#          10.0   2016.0     68
#          9.0    2016.0     66
#                 2017.0     65
#          12.0   2015.0     65
#          5.0    2017.0     63
#          1.0    2017.0     62
#          6.0    2017.0     62
#          1.0    2016.0     61
#          7.0    2016.0     59
#          12.0   2016.0     57
#          6.0    2016.0     57
#          2.0    2016.0     56
#          4.0    2016.0     54
#          11.0   2016.0     52
#          2.0    2017.0     52
#          8.0    2016.0     49
#          3.0    2016.0     41
#          5.0    2016.0     36
#          11.0   2017.0     34
# 85004.0  8.0    2016.0     88
#          2.0    2017.0     83
#          11.0   2016.0     77
#          4.0    2017.0     76
#          6.0    2017.0     75
# ...

# %%
n['UCR CRIME CATEGORY'].value_counts()
# Out:
# UCR CRIME CATEGORY
# LARCENY-THEFT                            66216
# BURGLARY                                 23648
# MOTOR VEHICLE THEFT                      14391
# DRUG OFFENSE                              9572
# AGGRAVATED ASSAULT                        9306
# ROBBERY                                   5640
# RAPE                                      1981
# ARSON                                      634
# MURDER AND NON-NEGLIGENT MANSLAUGHTER      289
# Name: count, dtype: int64

# %% [markdown]
# Adding column 'CRIME TYPE' for non-violent and violent crimes

# %%
n['CRIME TYPE'] = ''

# %%
n.loc[n['UCR CRIME CATEGORY'] == 'LARCENY-THEFT', 'CRIME TYPE'] = 'non-violent'
n.loc[n['UCR CRIME CATEGORY'] == 'BURGLARY', 'CRIME TYPE'] = 'non-violent'
n.loc[n['UCR CRIME CATEGORY'] == 'MOTOR VEHICLE THEFT',  'CRIME TYPE'] = 'non-violent'
n.loc[n['UCR CRIME CATEGORY'] == 'DRUG OFFENSE',  'CRIME TYPE'] = 'non-violent'
n.loc[n['UCR CRIME CATEGORY'] == 'ARSON', 'CRIME TYPE'] = 'non-violent'

n.loc[n['UCR CRIME CATEGORY'] == 'AGGRAVATED ASSAULT', 'CRIME TYPE']='violent'
n.loc[n['UCR CRIME CATEGORY'] == 'ROBBERY', 'CRIME TYPE']='violent'
n.loc[n['UCR CRIME CATEGORY'] == 'RAPE', 'CRIME TYPE']='violent'
n.loc[n['UCR CRIME CATEGORY'] ==  'MURDER AND NON-NEGLIGENT MANSLAUGHTER', 'CRIME TYPE']='violent'

# %%
n
# Out:
#                INC NUMBER    OCCURRED ON    OCCURRED TO   UCR CRIME CATEGORY  \
# 0               2.016E+14   11/1/15 0:00    1/9/16 0:00  MOTOR VEHICLE THEFT
# 1               2.016E+14   11/1/15 0:00            NaN                 RAPE
# 2               2.015E+14   11/1/15 0:00   11/1/15 9:00        LARCENY-THEFT
# 3               2.015E+14   11/1/15 0:00   11/1/15 5:00  MOTOR VEHICLE THEFT
# 4               2.015E+14   11/1/15 0:00  11/1/15 11:50  MOTOR VEHICLE THEFT
# ...                   ...            ...            ...                  ...
# 131672  201700000000000.0  11/17/17 4:15  11/17/17 4:30        LARCENY-THEFT
# 131673  201700000000000.0  11/17/17 5:00  11/17/17 9:50  MOTOR VEHICLE THEFT
# 131674  201700000000000.0  11/17/17 5:34            NaN   AGGRAVATED ASSAULT
# 131675  201700000000000.0  11/17/17 5:50  11/17/17 7:50             BURGLARY
# 131676  201700000000000.0  11/17/17 6:00  11/30/17 6:00             BURGLARY
#
# ...

# %%
ncrime = n.groupby('CRIME TYPE')

# %% [markdown]
# Checking to make sure the new column looks right

# %%
ncrime['UCR CRIME CATEGORY'].value_counts()
# Out:
# CRIME TYPE   UCR CRIME CATEGORY
# non-violent  LARCENY-THEFT                            66216
#              BURGLARY                                 23648
#              MOTOR VEHICLE THEFT                      14391
#              DRUG OFFENSE                              9572
#              ARSON                                      634
# violent      AGGRAVATED ASSAULT                        9306
#              ROBBERY                                   5640
#              RAPE                                      1981
#              MURDER AND NON-NEGLIGENT MANSLAUGHTER      289
# Name: count, dtype: int64

# %% [markdown]
# Count of crime type by zip code

# %%
nzip['CRIME TYPE'].value_counts()
# Out:
# ZIP      CRIME TYPE
# 85003.0  non-violent    1266
#          violent         247
# 85004.0  non-violent    1393
#          violent         257
# 85006.0  non-violent    2159
#                         ...
# 85383.0  violent           1
# 85392.0  non-violent       6
#          violent           2
# 85395.0  violent           2
# 85396.0  non-violent       4
# Name: count, Length: 170, dtype: int64

# %% [markdown]
# Crime type by year

# %%
ncrime.year.value_counts()
# Out:
# CRIME TYPE   year
# non-violent  2016.0    55473
#              2017.0    49719
#              2015.0     9006
# violent      2017.0     8292
#              2016.0     7753
#              2015.0     1118
# Name: count, dtype: int64

# %%
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from bs4 import BeautifulSoup
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
import os
import re
import pandas as pd
from string import punctuation

qa = pd.read_json('jeopardy.json')

english_stopwords = set(stopwords.words('english') + list(punctuation))

lemmatizer = WordNetLemmatizer()

# %%
qa
# Out:
#                                category    air_date  \
# 0                               HISTORY  2004-12-31
# 1       ESPN's TOP 10 ALL-TIME ATHLETES  2004-12-31
# 2           EVERYBODY TALKS ABOUT IT...  2004-12-31
# 3                      THE COMPANY LINE  2004-12-31
# 4                   EPITAPHS & TRIBUTES  2004-12-31
# ...                                 ...         ...
# 216925                   RIDDLE ME THIS  2006-05-11
# 216926                        "T" BIRDS  2006-05-11
# 216927           AUTHORS IN THEIR YOUTH  2006-05-11
# 216928                       QUOTATIONS  2006-05-11
# 216929                   HISTORIC NAMES  2006-05-11
#
#                                                  question  value  \
# 0       'For the last 8 years of his life, Galileo was...   $200
# 1       'No. 2: 1912 Olympian; football star at Carlis...   $200
# 2       'The city of Yuma in this state has a record a...   $200
# 3       'In 1963, live on "The Art Linkletter Show", t...   $200
# 4       'Signer of the Dec. of Indep., framer of the C...   $200
# ...                                                   ...    ...
# 216925  'This Puccini opera turns on the solution to 3...  $2000
# 216926  'In North America this term is properly applie...  $2000
# 216927  'In Penny Lane, where this "Hellraiser" grew u...  $2000
# 216928  'From Ft. Sill, Okla. he made the plea, Arizon...  $2000
# 216929  'A silent movie title includes the last name o...   None
#
#                                 answer             round  show_number
# 0                           Copernicus         Jeopardy!         4680
# 1                           Jim Thorpe         Jeopardy!         4680
# 2                              Arizona         Jeopardy!         4680
# 3                          McDonald\'s         Jeopardy!         4680
# 4                           John Adams         Jeopardy!         4680
# ...                                ...               ...          ...
# 216925                        Turandot  Double Jeopardy!         4999
# 216926                      a titmouse  Double Jeopardy!         4999
# 216927                    Clive Barker  Double Jeopardy!         4999
# 216928                        Geronimo  Double Jeopardy!         4999
# 216929  Grigori Alexandrovich Potemkin   Final Jeopardy!         4999
#
# [216930 rows x 7 columns]

# %%
qa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216930 entries, 0 to 216929
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   category     216930 non-null  object
#  1   air_date     216930 non-null  object
#  2   question     216930 non-null  object
#  3   value        213296 non-null  object
#  4   answer       216930 non-null  object
#  5   round        216930 non-null  object
#  6   show_number  216930 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 11.6+ MB

# %% [markdown]
# Getting an idea of what the value column looks like.

# %%
qa['value'].value_counts()
# Out:
# value
# $400       42244
# $800       31860
# $200       30455
# $600       20377
# $1000      19539
#            ...
# $5,401         1
# $1,183         1
# $1,203         1
# $11,600        1
# $11,200        1
# Name: count, Length: 149, dtype: int64

# %%
qa
# Out:
#                                category    air_date  \
# 0                               HISTORY  2004-12-31
# 1       ESPN's TOP 10 ALL-TIME ATHLETES  2004-12-31
# 2           EVERYBODY TALKS ABOUT IT...  2004-12-31
# 3                      THE COMPANY LINE  2004-12-31
# 4                   EPITAPHS & TRIBUTES  2004-12-31
# ...                                 ...         ...
# 216925                   RIDDLE ME THIS  2006-05-11
# 216926                        "T" BIRDS  2006-05-11
# 216927           AUTHORS IN THEIR YOUTH  2006-05-11
# 216928                       QUOTATIONS  2006-05-11
# 216929                   HISTORIC NAMES  2006-05-11
#
#                                                  question  value  \
# 0       'For the last 8 years of his life, Galileo was...   $200
# 1       'No. 2: 1912 Olympian; football star at Carlis...   $200
# 2       'The city of Yuma in this state has a record a...   $200
# 3       'In 1963, live on "The Art Linkletter Show", t...   $200
# 4       'Signer of the Dec. of Indep., framer of the C...   $200
# ...                                                   ...    ...
# 216925  'This Puccini opera turns on the solution to 3...  $2000
# 216926  'In North America this term is properly applie...  $2000
# 216927  'In Penny Lane, where this "Hellraiser" grew u...  $2000
# 216928  'From Ft. Sill, Okla. he made the plea, Arizon...  $2000
# 216929  'A silent movie title includes the last name o...   None
#
#                                 answer             round  show_number
# 0                           Copernicus         Jeopardy!         4680
# 1                           Jim Thorpe         Jeopardy!         4680
# 2                              Arizona         Jeopardy!         4680
# 3                          McDonald\'s         Jeopardy!         4680
# 4                           John Adams         Jeopardy!         4680
# ...                                ...               ...          ...
# 216925                        Turandot  Double Jeopardy!         4999
# 216926                      a titmouse  Double Jeopardy!         4999
# 216927                    Clive Barker  Double Jeopardy!         4999
# 216928                        Geronimo  Double Jeopardy!         4999
# 216929  Grigori Alexandrovich Potemkin   Final Jeopardy!         4999
#
# [216930 rows x 7 columns]

# %% [markdown]
# Changing value column datatype to string

# %%
qa['value'] = qa['value'].astype(str)

# %% [markdown]
# Adding column "value indicator" where 1 = high value and 0 = low value. Everything less than or equal to $600 is considered low value. Everything over $600 is high value.

# %%
qa['value indicator'] = qa['value'].apply(lambda x: 0 if x == '$200' or x == '$400' or x == 'None' or x == '$600' else 1)

# %% [markdown]
# Checking new column

# %%
qa
# Out:
#                                category    air_date  \
# 0                               HISTORY  2004-12-31
# 1       ESPN's TOP 10 ALL-TIME ATHLETES  2004-12-31
# 2           EVERYBODY TALKS ABOUT IT...  2004-12-31
# 3                      THE COMPANY LINE  2004-12-31
# 4                   EPITAPHS & TRIBUTES  2004-12-31
# ...                                 ...         ...
# 216925                   RIDDLE ME THIS  2006-05-11
# 216926                        "T" BIRDS  2006-05-11
# 216927           AUTHORS IN THEIR YOUTH  2006-05-11
# 216928                       QUOTATIONS  2006-05-11
# 216929                   HISTORIC NAMES  2006-05-11
#
#                                                  question  value  \
# 0       'For the last 8 years of his life, Galileo was...   $200
# 1       'No. 2: 1912 Olympian; football star at Carlis...   $200
# 2       'The city of Yuma in this state has a record a...   $200
# 3       'In 1963, live on "The Art Linkletter Show", t...   $200
# 4       'Signer of the Dec. of Indep., framer of the C...   $200
# ...                                                   ...    ...
# 216925  'This Puccini opera turns on the solution to 3...  $2000
# 216926  'In North America this term is properly applie...  $2000
# 216927  'In Penny Lane, where this "Hellraiser" grew u...  $2000
# 216928  'From Ft. Sill, Okla. he made the plea, Arizon...  $2000
# 216929  'A silent movie title includes the last name o...   None
#
#                                 answer             round  show_number  \
# 0                           Copernicus         Jeopardy!         4680
# 1                           Jim Thorpe         Jeopardy!         4680
# 2                              Arizona         Jeopardy!         4680
# 3                          McDonald\'s         Jeopardy!         4680
# 4                           John Adams         Jeopardy!         4680
# ...                                ...               ...          ...
# 216925                        Turandot  Double Jeopardy!         4999
# 216926                      a titmouse  Double Jeopardy!         4999
# 216927                    Clive Barker  Double Jeopardy!         4999
# 216928                        Geronimo  Double Jeopardy!         4999
# 216929  Grigori Alexandrovich Potemkin   Final Jeopardy!         4999
#
#         value indicator
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 216925                1
# 216926                1
# 216927                1
# 216928                1
# 216929                0
#
# [216930 rows x 8 columns]

# %% [markdown]
# Cleaning and lemmatizing the text in "question" column.

# %%
def clean_qs(question):
    question = question.lower()
    toke_q = word_tokenize(question)
    
    wordlist = []
    for word in toke_q:
        if word not in english_stopwords:
            wordlist.append(word)
    
    wordlist2 = []
    for eachword in wordlist:
        wordlist2.append(lemmatizer.lemmatize(eachword))
    question = [' '.join(wordlist2)]
    question = str(question)
    
    return question

# %%
qa['question'] = qa['question'].apply(clean_qs)

# %%
qa
# Out:
#                                category    air_date  \
# 0                               HISTORY  2004-12-31
# 1       ESPN's TOP 10 ALL-TIME ATHLETES  2004-12-31
# 2           EVERYBODY TALKS ABOUT IT...  2004-12-31
# 3                      THE COMPANY LINE  2004-12-31
# 4                   EPITAPHS & TRIBUTES  2004-12-31
# ...                                 ...         ...
# 216925                   RIDDLE ME THIS  2006-05-11
# 216926                        "T" BIRDS  2006-05-11
# 216927           AUTHORS IN THEIR YOUTH  2006-05-11
# 216928                       QUOTATIONS  2006-05-11
# 216929                   HISTORIC NAMES  2006-05-11
#
#                                                  question  value  \
# 0       ["'for last 8 year life galileo house arrest e...   $200
# 1       ["'no 2 1912 olympian football star carlisle i...   $200
# 2       ["'the city yuma state record average 4,055 ho...   $200
# 3       ["'in 1963 live `` art linkletter show '' comp...   $200
# 4       ["'signer dec. indep. framer constitution mass...   $200
# ...                                                   ...    ...
# 216925  ["'this puccini opera turn solution 3 riddle p...  $2000
# 216926  ["'in north america term properly applied 4 sp...  $2000
# 216927  ["'in penny lane `` hellraiser '' grew barber ...  $2000
# 216928  ["'from ft. sill okla. made plea arizona land ...  $2000
# 216929  ['silent movie title includes last name 18th c...   None
#
#                                 answer             round  show_number  \
# 0                           Copernicus         Jeopardy!         4680
# 1                           Jim Thorpe         Jeopardy!         4680
# 2                              Arizona         Jeopardy!         4680
# 3                          McDonald\'s         Jeopardy!         4680
# 4                           John Adams         Jeopardy!         4680
# ...                                ...               ...          ...
# 216925                        Turandot  Double Jeopardy!         4999
# 216926                      a titmouse  Double Jeopardy!         4999
# 216927                    Clive Barker  Double Jeopardy!         4999
# 216928                        Geronimo  Double Jeopardy!         4999
# 216929  Grigori Alexandrovich Potemkin   Final Jeopardy!         4999
#
#         value indicator
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 216925                1
# 216926                1
# 216927                1
# 216928                1
# 216929                0
#
# [216930 rows x 8 columns]

# %% [markdown]
# Creating train and test sets for use with naive bayes.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(qa.question, qa['value indicator'], random_state=1)

# %%
tfidf_vectorizer = TfidfVectorizer(use_idf = True)
X_train_tf = tfidf_vectorizer.fit_transform(X_train)
X_test_tf = tfidf_vectorizer.transform(X_test)

# %%
naive_bayes = MultinomialNB()
naive_bayes.fit(X_train_tf, Y_train)
predictions = naive_bayes.predict(X_test_tf)

# %% [markdown]
# Looking at accuracy of the prediction of value based on contents of the quesion.

# %%
print('Accuracy: ', accuracy_score(Y_test, predictions))
# Out:
# Accuracy:  0.5525418103368798
